# %%
import pandas as pd
import xlrd
xlsfile = "B_vol2.xlsx"
book = xlrd.open_workbook(xlsfile)
table = book.sheet_by_index(0)
nrows = table.nrows
ncols = table.ncols
print("The table all row is %d,col is %s" %(nrows,ncols))
# Out:
# The table all row is 2600,col is 1

# %%
data = []
for i in range(nrows):
    data.append(table.cell(i,0).value)

# %%
data_rev = list(reversed(data))

# %%
import re
m = re.compile('(\d+\u3001)|([A-D]\.)')
f = [re.search(m,data_rev[i]) for i in range(len(data_rev))]

# %%
for i in range(len(f)-1):
    if f[i] is None:
        data_rev[i+1] = '%s%s' % (data_rev[i+1], data_rev[i])
        data_rev[i] = 'flag'

# %%
for i in range(len(data_rev)-1,-1,-1):
    if data_rev[i] == 'flag':
        data_rev.pop(i)
data = list(reversed(data_rev))

# %%
s_num = '\D*((?:\d)+)(\u3001)\s*(.+)'    #匹配题号
colnum2qnum = [None] * len(data)    #行数和题号
colnum2qnum[0] = 1
qnum_que = [[],[]]    # 题号和问题
qnum_que[0].append(re.search(s_num, data[0]).group(1))
qnum_que[1].append(re.search(s_num, data[0]).group(3))
for i in range(1,len(data)):
    m = re.search(s_num, data[i])
    if m is None:
        colnum2qnum[i] = colnum2qnum[i-1]
    else:
        qnum_que[0].append(m.group(1))
        qnum_que[1].append(m.group(3))
        colnum2qnum[i] = int((m.group(1)))

#pat_slt = '([A-D]\.[\u4e00-\u9fa5]+)\s+(([A-D]\.[\u4e00-\u9fa5]+)?)'    #匹配ABCD选项  A.XXXX    B.XXXX
pat_slt = '([A-Z]\.\S+)\s*([A-Z]\.\s*\S+)?'
#pat_slt = '([A-D]\.\S?\s{0,2}[\S]{0,2}\s{0,2}\S+)\s*(\1)?'

# s = '(%s\.[\u4e00-\u9fa5]+)' % (alph) 
# mid_value = [re.match(pat_slt, data[i]) for i in range(len(data))]
form = [[],[]] # quesion num, select
for i in range(len(data)):
    m = re.search(pat_slt, data[i])
    if m is not None:
        k = list(m.groups())
        if None in k: k.remove(None)
        form[0].extend([colnum2qnum[i]]*len(k))
        form[1].extend(k)

final = [[],[],[]]
final[0] = qnum_que[0]
final[1] = qnum_que[1]

# %%
df = pd.DataFrame({'key':form[0],'data':form[1]})
grouped=df['data'].groupby(df['key'])
gr = []
for name,group in grouped:
    final[2].append(' '.join(list(grouped.get_group(name))))

# %%
form[1]
# Out:
# ['A.质量检查员',
#  'B.施工员',
#  'C.项目经理',
#  'D.安全员',
#  'A.2',
#  'B.3',
#  'C.4',
#  'D.5',
#  'A.施工许可管理办法',
#  'B.建筑法',
#  'C.建设工程质量管理条例',
#  'D.工程建设强制性标准',
#  'A.砌体结构构件',
#  'B.施工工艺',
#  'C.砂浆种类',
#  'D.抗震设防烈度',
#  'A.国务院',
#  'B.建设部',
#  'C.国家计委',
#  'D.国家发改委',
#  'A.10%',
#  'B.20%',
#  'C.30%',
#  'D.40%',
#  'A.天然砂',
#  'B.河砂',
#  'C.海砂',
#  'D.山砂',
#  'A.建设单位',
#  'B.监理单位',
#  'C.质量监督单位',
#  'D.档案管理单位',
#  'A.分层开挖',
#  'B.分段开挖',
#  'C.分区开挖',
#  'D.分块开挖',
#  'A.若设计无要求，至少保留7d后再浇筑',
#  'B.填充后浇带，可采用高膨胀混凝土',
#  'C.膨胀混凝土强度等级与原结构强度相同',
#  'D.填充混凝土保持至少14d的湿润养护',
#  'A.挤浆法',
#  'B.刮浆法',
#  'C.满口灰法',
#  'D.“三一”砌法',
#  'A.30mm',
#  'B.50mm',
#  'C.80m',
#  'D.100mm',
#  'A.7d',
#  'B.10d',
#  'C.14d',
#  'D.15d',
#  'A.1.2N/mm2',
#  'B.2.5N/mm2',
#  'C.设计强度的25%',
#  'D.设计强度的50%',
#  'A.1.5',
#  'B.2.0',
#  'C.2.2',
#  'D.2.5',
#  'A.板的钢筋在上，次梁钢筋居中，主梁钢筋在下',
#  'B.次梁钢筋在上，板的钢筋居中，主梁钢筋在下',
#  'C.主梁钢筋在上，次梁钢筋居中，板的钢筋在下',
#  'D.板的钢筋在上，主梁钢筋居中，次梁钢筋在下',
#  'A.平行于屋脊',
#  'B.垂直于屋脊',
#  'C.与屋脊呈45度角',
#  'D.上下层相互垂直',
#  'A.240mm',
#  'B.360mm',
#  'C.500mm',
#  'D.1000mm',
#  'A.喷涂施工',
#  'B.滚涂施工',
#  'C.刮涂施工',
#  'D.刷涂施工',
#  'A.2-4',
#  'B.5-7',
#  'C.8-10',
#  'D.10-12',
#  'A.技术',
#  'B.燃烧',
#  'C.化学',
#  'D.物理',
#  'A.屈服强度',
#  'B.可焊性',
#  'C.延伸率',
#  'D.极限抗拉强度',
#  'A.挤浆法',
#  'B.刮浆法',
#  'C.满口灰发',
#  'D.“三一”砌筑法',
#  'A.1.5',
#  'B.2.0',
#  'C.2.2',
#  'D.2.5',
#  'A.开口',
#  'B.拉钩',
#  'C.封闭',
#  'D.半封闭',
#  'A.适筋',
#  'B.少筋',
#  'C.中筋',
#  'D.超筋',
#  'A.5',
#  'B.10',
#  'C.20',
#  'D.30',
#  'A.0.2',
#  'B.0.5',
#  'C.1',
#  'D.2',
#  'A.50%',
#  'B.60%',
#  'C.75%',
#  'D.100%',
#  'A.振捣器振动部分的1.25倍',
#  'B.150㎜',
#  'C.200㎜',
#  'D.250㎜',
#  'A.建筑',
#  'B.勘察、设计',
#  'C.设计',
#  'D.监理',
#  'A.建设单位',
#  'B.施工单位',
#  'C.监理单位',
#  'D.设计单位',
#  'A.建设单位',
#  'B.施工单位',
#  'C.监理单位',
#  'D.设计单位',
#  'A.建设单位',
#  'B.施工单位',
#  'C.监理单位',
#  'D.设计单位',
#  'A.操作者',
#  'B.专业工长',
#  'C.项目专业质量检查员',
#  'D.项目专业技术负责人',
#  'A.钢化玻璃',
#  'B.镀膜玻璃',
#  'C.夹丝玻璃',
#  'D.中空玻璃',
#  'A.骨架式',
#  'B.锚固式',
#  'C.背挂式',
#  'D.倒挂式',
#  'A.内高外平',
#  'B.外高内低',
#  'C.内高外低',
#  'D.外高内平',
#  'A.细木工板',
#  'B.实木地板',
#  'C.纤维板',
#  'D.多层板',
#  'A.满粘法',
#  'B.点粘法',
#  'C.挂粘法',
#  'D.空铺法',
#  'A.泡沫塑料',
#  'B.玻璃棉',
#  'C.泡沫石棉',
#  'D.膨胀珍珠岩',
#  'A.1/2',
#  'B.1/3',
#  'C.1/5',
#  'D.2/3',
#  'A.100',
#  'B.120',
#  'C.140',
#  'D.160',
#  'A.100',
#  'B.150',
#  'C.200',
#  'D.250',
#  'A.围护墙',
#  'B.承重墙',
#  'C.隔墙',
#  'D.非承重墙',
#  'A.不超过结构最小截面尺寸的1/4，钢筋最小间距的2/4。',
#  'B.不超过结构最小截面尺寸的1/4，钢筋最小间距的3/4；',
#  'C.不超过结构最小截面尺寸的2/4，钢筋最小间距的3/4；',
#  'D.不超过结构最小截面尺寸的2/4，钢筋最小间距的2/4。',
#  'A.混凝土的终凝时间',
#  'B.混凝土的初凝时间',
#  'C.终凝加初凝时间',
#  'D.混凝土搅拌时间的2倍',
#  'A.不能使用',
#  'B.仍可正常使用',
#  'C.降低标号使用',
#  'D.经试验鉴定后，按试验结果使用',
#  'A.3',
#  'B.7',
#  'C.9',
#  'D.14',
#  'A.监理工程师',
#  'B.总监理工程师',
#  'C.现场工程师',
#  'D.总工程师',
#  'A.建设单位',
#  'B.施工单位',
#  'C.监理单位',
#  'D.设计单位',
#  'A.计量、计数或计量-计数的抽样方案；',
#  'B.一次、二次或多次抽样方案；',
#  'C.对重要的检验项目，当有简易快速的检验方法时，选用全数检验方案；',
#  'D.根据生产的不连续性和生产控制的不稳定性情况，采用调整型抽样方案；',
#  'A.具备独立施工条件',
#  'B.能形成独立使用功能',
#  'C.具备独立专业要求',
#  'D.能形成共同的技术要求',
#  'A.项目专业技术负责人',
#  'B.项目专业质量检查员',
#  'C.项目专业施工人员',
#  'D.项目现场施工人员',
#  'A.监理工程师',
#  'B.总监理工程师',
#  'C.现场工程师',
#  'D.总工程师',
#  'A.返工',
#  'B.返修',
#  'C.检测鉴定',
#  'D.加固处理',
#  'A.建设',
#  'B.勘察、设计',
#  'C.监理',
#  'D.施工',
#  'A.要',
#  'B.宜',
#  'C.应',
#  'D.必须',
#  'A.3',
#  'B.4',
#  'C.5',
#  'D.6',
#  'A.300',
#  'B.400',
#  'C.500',
#  'D.600',
#  'A.1.25',
#  'B.1.3',
#  'C.1.35',
#  'D.1.5',
#  'A.上部',
#  'B.中部',
#  'C.下部',
#  'D.侧部',
#  'A.1.5',
#  'B.0.8',
#  'C.1',
#  'D.0.5',
#  'A.20',
#  'B.35',
#  'C.45',
#  'D.50',
#  'A.0.5',
#  'B.0.75',
#  'C.0.8',
#  'D.1.0',
#  'A.4',
#  'B.2',
#  'C.3',
#  'D.1',
#  'A.200m3或300t',
#  'B.300m3或450t',
#  'C.400m3或600t',
#  'D.500m3或800t',
#  'A.24',
#  'B.12',
#  'C.6',
#  'D.2',
#  'A.80',
#  'B.70',
#  'C.50',
#  'D.100',
#  'A.4×4',
#  'B.5×5',
#  'C.6×6',
#  'D.12×12',
#  'A.500',
#  'B.700',
#  'C.900',
#  'D.1000',
#  'A.10',
#  'B.15',
#  'C.20',
#  'D.25',
#  'A.保证项目',
#  'B.一般项目',
#  'C.基本项目',
#  'D.允许偏差项目',
#  'A.验收部位',
#  'B.工序',
#  'C.检验批',
#  'D.专业验收',
#  'A.监理单位',
#  'B.施工单位',
#  'C.建设单位',
#  'D.共同',
#  'A.建筑装饰',
#  'B.建筑装修',
#  'C.门窗',
#  'D.建筑装饰装修',
#  'A.工种',
#  'B.材料',
#  'C.施工工艺',
#  'D.设备类别E.A+B+C+D',
#  'A.建设单位',
#  'B.建设行政主管部门',
#  'C.工程质量监督机构',
#  'D.建设单位和工程质量监督机构',
#  'A.符合规范规定质量合格的工程',
#  'B.不符合规范规定质量不合格，但可使用工程',
#  'C.质量不符合要求，但可协商验收的工程',
#  'D.不符合规范规定质量不合格，不可使用工程',
#  'A.3',
#  'B.4',
#  'C.5',
#  'D.6',
#  'A.竣工验收',
#  'B.竣工预验收',
#  'C.竣工检查',
#  'D.验收检查',
#  'A.钢筋的种类及规格',
#  'B.钢筋的可焊性及钢材质量',
#  'C.钢筋的可焊性和焊接工艺水平',
#  'D.钢筋的质量和焊接工艺水平',
#  'A.骨料的最大粒径不超过板厚的1/4，且不得超过60㎜',
#  'B.骨料的最大粒径不超过板厚的2/4，且不得超过60㎜',
#  'C.骨料的最大粒径不超过板厚的1/3，且不得超过40㎜',
#  'D.骨料的最大粒径不超过板厚的2/3，且不得超过60㎜',
#  'A.1',
#  'B.2',
#  'C.3',
#  'D.4',
#  'A.100%',
#  'B.90%及以上',
#  'C.85%及以上',
#  'D.80%及以上',
#  'A.100',
#  'B.200',
#  'C.150',
#  'D.250',
#  'A.5',
#  'B.8',
#  'C.10',
#  'D.3',
#  'A.15',
#  'B.25',
#  'C.30',
#  'D.35',
#  'A.四',
#  'B.五',
#  'C.六',
#  'D.七',
#  'A.10',
#  'B.0',
#  'C.5',
#  'D.-5',
#  'A.1.2',
#  'B.1.25',
#  'C.1.3',
#  'D.1.15',
#  'A.15天',
#  'B.20天',
#  'C.1个月',
#  'D.45天',
#  'A.安全性',
#  'B.经济性',
#  'C.适用性',
#  'D.耐久性',
#  'A.自重小',
#  'B.耐久性能好',
#  'C.保温性能差',
#  'D.抗压性能差',
#  'A.100',
#  'B.120',
#  'C.150',
#  'D.200',
#  'A.2-5',
#  'B.2-6',
#  'C.3-8',
#  'D.4-8',
#  'A.剪力墙',
#  'B.框架',
#  'C.剪力墙和框架',
#  'D.不能确定',
#  'A.混凝土强度',
#  'B.钢筋的直径',
#  'C.钢筋的材质',
#  'D.钢筋表面粗糙度',
#  'A.可模性好',
#  'B.耐火性差',
#  'C.维修费用高',
#  'D.抗裂性较好',
#  'A.砌体的强度',
#  'B.局部的抗压强度',
#  'C.高厚比',
#  'D.砖的强度等级',
#  'A.墙长的中间部位',
#  'B.墙体门窗洞口处',
#  'C.墙断面尺寸较大部位',
#  'D.墙断面尺寸较小部位',
#  'A.抗压强度较高，抗拉强度较高',
#  'B.抗压强度较高，抗拉强度较低',
#  'C.抗压强度较低，抗拉强度较高',
#  'D.抗压强度较低，抗拉强度较低',
#  'A.构造柱',
#  'B.框架梁',
#  'C.楼板中部',
#  'D.梁节点',
#  'A.钢化玻璃',
#  'B.夹层玻璃',
#  'C.夹丝玻璃',
#  'D.镀膜玻璃',
#  'A.防水砂浆',
#  'B.防水混凝土',
#  'C.掺有外加剂的砂浆',
#  'D.密封材料',
#  'A.拉伸强度和延伸率低',
#  'B.温度稳定性较好',
#  'C.低温不易脆裂',
#  'D.耐老化性较好',
#  'A.3',
#  'B.4',
#  'C.5',
#  'D.6',
#  'A.粉煤灰',
#  'B.矿渣',
#  'C.粗砂',
#  'D.碎石',
#  'A.分段分层',
#  'B.斜面分层',
#  'C.全面分层',
#  'D.交叉分层',
#  'A.梁跨中1/3处',
#  'B.梁支座处',
#  'C.距梁支座1/3处',
#  'D.可随意设置',
#  'A.60',
#  'B.70',
#  'C.80',
#  'D.100',
#  'A.正相关',
#  'B.负相关',
#  'C.非线性关系',
#  'D.不相关',
#  'A.5%',
#  'B.8%',
#  'C.10%',
#  'D.12%',
#  'A.事后的、静态的',
#  'B.事中的、动态的',
#  'C.事前的、静态的',
#  'D.事中的、静态的',
#  'A.施工方案',
#  'B.施工日志',
#  'C.背水内表面结构展开图',
#  'D.防水混凝土配合比',
#  'A.1-2',
#  'B.2-3',
#  'C.3-4',
#  'D.4-5',
#  'A.30',
#  'B.25',
#  'C.15',
#  'D.10',
#  'A.5000',
#  'B.10000',
#  'C.30000',
#  'D.50000',
#  'A.正态',
#  'B.直线',
#  'C.抛特线',
#  'D.正比例',
#  'A.1100cm',
#  'B.990mm',
#  'C.770mm',
#  'D.500mm',
#  'A.42天',
#  'B.28天',
#  'C.14天',
#  'D.7天',
#  'A.二',
#  'B.三',
#  'C.四',
#  'D.五',
#  'A.25',
#  'B.25',
#  'C.26',
#  'D.25',
#  'A.300mm',
#  'B.400mm',
#  'C.500mm',
#  'D.600mm',
#  'A.-3',
#  'B.-5',
#  'C.3',
#  'D.5',
#  'A.初凝前',
#  'B.初凝后',
#  'C.终凝前',
#  'D.终凝后',
#  'A.200',
#  'B.250',
#  'C.300',
#  'D.350',
#  'A.0．1mm',
#  'B.0．2mm',
#  'C.0．5mm',
#  'D.1mm',
#  'A.人员素质',
#  'B.工程材料',
#  'C.施工机械',
#  'D.工艺方法',
#  'A.搅拌地点',
#  'B.浇筑地点',
#  'C.搅拌站实验室',
#  'D.现场试验室',
#  'A.C15',
#  'B.C20',
#  'C.C30',
#  'D.C40',
#  'A.28',
#  'B.14',
#  'C.7',
#  'D.30',
#  'A.1/2',
#  'B.1/3',
#  'C.1/4',
#  'D.1/5',
#  'A.分部',
#  'B.分项',
#  'C.子分部',
#  'D.检验批',
#  'A.15mm',
#  'B.20mm',
#  'C.10mm',
#  'D.25mm',
#  'A.25%',
#  'B.30%',
#  'C.35%',
#  'D.40%',
#  'A.300mm',
#  'B.500mm',
#  'C.800mm',
#  'D.1000mm',
#  'A.60',
#  'B.90',
#  'C.120',
#  'D.150',
#  'A.5',
#  'B.8',
#  'C.5',
#  'D.8',
#  'A.3m',
#  'B.4m',
#  'C.5m',
#  'D.6m',
#  'A.22',
#  'B.25',
#  'C.25',
#  'D.28',
#  'A.55%',
#  'B.75%',
#  'C.85%',
#  'D.100%',
#  'A.6',
#  'B.8',
#  'C.6',
#  'D.6',
#  'A.300mm',
#  'B.500mm',
#  'C.800mm',
#  'D.1000mm',
#  'A.严禁',
#  'B.可以',
#  'C.宜',
#  'D.不宜',
#  'A.1.2N/mm2',
#  'B.1.5N/mm2',
#  'C.1.8N/mm2',
#  'D.2.0N/mm2',
#  'A.10',
#  'B.5',
#  'C.8',
#  'D.4',
#  'A.100mm',
#  'B.150mm',
#  'C.200mm',
#  'D.250mm',
#  'A.500mm',
#  'B.700mm',
#  'C.800mm',
#  'D.1000mm',
#  'A.0℃',
#  'B.-2℃',
#  'C.5℃',
#  'D.10℃',
#  'A.15N/mm2',
#  'B.21N/mm2',
#  'C.22.5N/mm2',
#  'D.30N/mm2',
#  'A.抗压强度',
#  'B.抗折强度',
#  'C.抗剪强度',
#  'D.抗拉强度',
#  'A.200',
#  'B.300',
#  'C.400',
#  'D.500',
#  'A.2m',
#  'B.4m',
#  'C.6m',
#  'D.8m',
#  'A.监理认可手续',
#  'B.设计变更文件',
#  'C.施工员签证',
#  'D.甲方认可签证',
#  'A.铁钉',
#  'B.膨胀螺栓',
#  'C.钢钉',
#  'D.射钉',
#  'A.设计单位',
#  'B.监理单位',
#  'C.具备相应资质的施工单位',
#  'D.原结构设计单位或具备相应资质的设计单位',
#  'A.0.6',
#  'B.0.7',
#  'C.0.8',
#  'D.0.9',
#  'A.120mm厚墙',
#  'B.砌体门窗洞口两侧450mm处',
#  'C.独立柱',
#  'D.宽度为800mm的窗间墙',
#  'A.300',
#  'B.500',
#  'C.750',
#  'D.1000',
#  'A.一级',
#  'B.二级',
#  'C.三级',
#  'D.四级',
#  'A.1%',
#  'B.2%',
#  'C.3%',
#  'D.4%',
#  'A.1.0m',
#  'B.1.5m',
#  'C.1.8m',
#  'D.2.0m',
#  'A.200mm',
#  'B.250mm',
#  'C.300mm',
#  'D.500mm',
#  'A.100mm',
#  'B.200mm',
#  'C.300mm',
#  'D.400mm',
#  'A.碱性硅酮结构密封胶',
#  'B.中性硅酮结构密封胶',
#  'C.酸性硅酮耐候密封胶',
#  'D.中性硅酮耐候密封胶',
#  'A.3',
#  'B.4',
#  'C.5',
#  'D.6',
#  'A.10—20',
#  'B.15—30',
#  'C.20—30',
#  'D.10—30',
#  'A.30',
#  'B.35',
#  'C.40',
#  'D.50',
#  'A.50%',
#  'B.75%',
#  'C.90%',
#  'D.100%',
#  'A.碳含量越高可焊性越高',
#  'B.碳含量越低可焊性越高',
#  'C.碳含量越低可焊性越低',
#  'D.可焊性不随碳含量的变化而变化',
#  'A.20',
#  'B.25',
#  'C.30',
#  'D.35',
#  'A.胶砂法',
#  'B.立方体抗压强度试验法',
#  'C.劈裂实验法',
#  'D.维勃稠度仪法',
#  'A.12h',
#  'B.24h',
#  'C.混凝土终凝前和1.2N/mm2',
#  'D.混凝土终凝后',
#  'A.10',
#  'B.9',
#  'C.8',
#  'D.7',
#  'A.12',
#  'B.10',
#  'C.8',
#  'D.6',
#  'A.均布面荷载',
#  'B.线荷载',
#  'C.集中荷载',
#  'D.分散荷载',
#  'A.强度',
#  'B.韧度',
#  'C.伸长率',
#  'D.变形',
#  'A.突弯',
#  'B.破坏',
#  'C.失效',
#  'D.失稳',
#  'A.抗压强度',
#  'B.抗折强度',
#  'C.抗剪强度',
#  'D.抗压强度及抗折强度',
#  'A.结构自重',
#  'B.雪荷载',
#  'C.风荷载',
#  'D.积灰荷载',
#  'A.施工现场砌块堆放整齐，堆放高度１.9m',
#  'B.常温情况下砌筑砖砌体时，提前２天浇水湿润',
#  'C.砖砌体的水平灰缝厚度为11mm',
#  'D.必须留置的临时间断砌成直槎',
#  'A.混凝土',
#  'B.普通透水墙',
#  'C.多孔砖',
#  'D.混凝土小型空心砌块',
#  'A.受压承载力',
#  'B.受剪承载力',
#  'C.受剪承载力',
#  'D.受剪承载力',
#  'A.0.5',
#  'B.0.75',
#  'C.0.9',
#  'D.1.2',
#  'A.25%',
#  'B.50%',
#  'C.75%',
#  'D.不限制',
#  'A.焊接',
#  'B.挤压套筒连接',
#  'C.绑扎搭接',
#  'D.直螺纹连接',
#  'A.12',
#  'B.24',
#  'C.36',
#  'D.48',
#  'A.20',
#  'B.25',
#  'C.30',
#  'D.50',
#  'A.3',
#  'B.5',
#  'C.7',
#  'D.14',
#  'A.1.5',
#  'B.3',
#  'C.5',
#  'D.10',
#  'A.2mm—4mm',
#  'B.3mm--6mm',
#  'C.4mm--8mm',
#  'D.5mm--10mm',
#  'A.0.5N/mm2',
#  'B.1.0N/mm2',
#  'C.1.5N/mm2',
#  'D.2.0N/mm2',
#  'A.15',
#  'B.20',
#  'C.25',
#  'D.30',
#  'A.12',
#  'B.10',
#  'C.5',
#  'D.15',
#  'A.6mm',
#  'B.9mm',
#  'C.10mm',
#  'D.-6mm',
#  'A.梁的高度较小时，梁的钢筋宜直接在梁底模上绑扎',
#  'B.梁的高度较大时，梁的钢筋宜架空在梁模板上绑扎',
#  'C.板、次梁与主梁交叉处，板的钢筋在上，次梁的钢筋居中，主梁的钢筋在下',
#  'D.框架节点处钢筋穿插稠密时，应保证梁顶面主筋间的净距最小值10mm',
#  'A.1',
#  'B.2',
#  'C.3',
#  'D.4',
#  'A.先两端张拉，后浇筑混凝土',
#  'B.先浇筑混凝土，后一端张拉，一端锚固',
#  'C.先浇筑混凝土，后两端同时或分段张拉',
#  'D.先一端张拉，一端锚固，后浇筑混凝土',
#  'A.框架柱、牛腿及柱帽等钢筋，应放在柱子纵向钢筋的外侧',
#  'B.柱中的竖向钢筋搭接时，角部钢筋的弯钩应与模板成60度',
#  'C.圆形柱竖向钢筋搭接时，角部钢筋的弯钩应与模板切线垂直',
#  'D.柱中的竖向钢筋搭接时，中间钢筋的弯钩应与模板成45度',
#  'A.不宜设在变形缝、构造柱处',
#  'B.砌筑高度不宜大于6米',
#  'C.宜在门窗洞口',
#  'D.相邻工作段的砌筑高度不得超过两个楼层高度',
#  'A.上下皮砌块的竖向灰缝应相互错开，并不小于100mm',
#  'B.灰缝应横平竖直，砂浆饱满，水平灰缝饱满的不应小于90%，宽度宜为20mm',
#  'C.竖向灰缝砂浆饱满度不应小于80%，宽度宜为10mm',
#  'D.加气混凝土墙上不得留设脚手眼',
#  'A.先砌墙，后绑扎构造柱钢筋',
#  'B.构造柱沿高度方向每1000mm设一道拉结筋',
#  'C.马牙槎沿高度方向的尺寸不超过500mm',
#  'D.马牙搓从每层柱脚开始，先退后进',
#  'A.1.2米',
#  'B.1.8米',
#  'C.2.4米',
#  'D.2.7米',
#  'A.钢丝网',
#  'B.泰柏板',
#  'C.空心砖墙',
#  'D.石灰砂浆层',
#  'A.其延长米间距不得大于10米',
#  'B.房屋转角处应设缝处理',
#  'C.散水、明沟和台阶等于建筑物连接处应设缝处理',
#  'D.缝的宽度为15~20mm缝内填水泥砂浆',
#  'A.先低跨后高跨，先远后近',
#  'B.先高跨后低跨，先远后近',
#  'C.先低跨后高跨，先近后远',
#  'D.先高跨后低跨，先近后远',
#  'A.纸筋灰',
#  'B.麻刀灰',
#  'C.高等级砂浆',
#  'D.干铺卷材',
#  'A.厚度小于3mm的高聚物改性沥青卷材，严禁采用热熔法施工',
#  'B.底板垫层混凝土卷材宜采用实铺法或满粘法',
#  'C.两幅卷材短边和长边的搭接宽度均不应小于150mm',
#  'D.上下两层和相邻两幅卷材的接缝应错开1/4~1/3幅宽',
#  'A.170～220mm',
#  'B.180～240mm',
#  'C.180～250mm',
#  'D.185～255mm',
#  'A.小于195mm',
#  'B.小于190mm',
#  'C.小于185mm',
#  'D.小于180mm',
#  'A.不少于2Φ4mm纵向焊接钢筋网片和钢筋间距不大于300mm的横向焊接钢筋网片',
#  'B.不少于2Φ4mm纵向焊接钢筋网片和钢筋间距不大于200mm的横向焊接钢筋网片',
#  'C.不少于3Φ4mm纵向焊接钢筋网片和钢筋间距不大于300mm的横向焊接钢筋网片',
#  'D.不少于3Φ4mm纵向焊接钢筋网片和钢筋间距不大于200mm的横向焊接钢筋网片',
#  'A.加气混凝土砌块可以建筑物底层地面以下部位砌筑',
#  'B.填充墙砌体工程中，加气混凝土砌块砌筑时，其产品龄期不应超过28d',
#  'C.加气混凝土砌块不得在经常处于80℃以上高温环境中砌筑',
#  'D.填充墙砌体工程中，加气混凝土砌块砌筑时，应保持绝对干燥',
#  'A.4～8mm',
#  'B.6～10mm',
#  'C.8～12mm',
#  'D.10～14mm',
#  'A.空心砖',
#  'B.加气混凝土砌块',
#  'C.轻骨料混凝土小型空心砌块',
#  'D.蒸压加气混凝土砌块',
#  'A.1件',
#  'B.2件',
#  'C.3件',
#  'D.4件',
#  'A.1件',
#  'B.2件',
#  'C.3件',
#  'D.4件',
#  'A.HPB235级',
#  'B.HRB335',
#  'C.HRB400',
#  'D.RRB335',
#  'A.观察检查',
#  'B.检查进场复验报告',
#  'C.检查化学成分等专项检验报告',
#  'D.检查产品出厂检验报告',
#  'A.灰土垫层厚度不应小于100mm',
#  'B.砂垫层厚度不应小于60mm',
#  'C.碎石碎砖垫层厚度不应小于100mm',
#  'D.水泥混凝土垫层不应小于80mm',
#  'A.混凝土护壁',
#  'B.砖砌体护壁',
#  'C.沉井护壁',
#  'D.钢套管护壁',
#  'A.400',
#  'B.300',
#  'C.200',
#  'D.150',
#  'A.考核评价',
#  'B.质量控制',
#  'C.监督检查',
#  'D.质量管理',
#  'A.检验批',
#  'B.分项工程',
#  'C.分部工程',
#  'D.施工作业过程',
#  'A.工程材料',
#  'B.机械设备',
#  'C.方法',
#  'D.环境条件',
#  'A.2mm',
#  'B.3mm',
#  'C.4mm',
#  'D.5mm',
#  'A.15㎜',
#  'B.20㎜',
#  'C.25㎜',
#  'D.30㎜',
#  'A.50%',
#  'B.60%',
#  'C.70%',
#  'D.80%',
#  'A.15mm',
#  'B.20mm',
#  'C.25mm',
#  'D.30mm',
#  'A.1.1',
#  'B.1.2',
#  'C.1.25',
#  'D.1.3',
#  'A.32.5',
#  'B.42.5',
#  'C.46.5',
#  'D.52.5',
#  'A.抗拉强度',
#  'B.抗折强度',
#  'C.抗侵蚀性',
#  'D.抗压强度',
#  'A.边长为100的立方体',
#  'B.边长为150的立方体',
#  'C.150*150*100',
#  'D.边长为70.7的立方体',
#  'A.2',
#  'B.3',
#  'C.4',
#  'D.5',
#  'A.直槎',
#  'B.马牙槎',
#  'C.斜槎',
#  'D.按实际留槎',
#  'A.2',
#  'B.3',
#  'C.4',
#  'D.5',
#  'A.防火层可以与幕墙玻璃直接接触',
#  'B.同一玻璃幕墙单元可以跨越两个防火分区',
#  'C.幕墙的金属框架应与主体结构的防雷体系可靠连接',
#  'D.防火层承托板可以采用铝板',
#  'A.办公楼',
#  'B.旅馆',
#  'C.餐厅',
#  'D.住宅',
#  'A.钢化玻璃',
#  'B.夹层玻璃',
#  'C.净片玻璃',
#  'D.钢化夹层玻璃',
#  'A.基桩打到基层深度',
#  'B.桩长',
#  'C.结头处焊接',
#  'D.打入深度',
#  'A.砌体结构',
#  'B.钢结构',
#  'C.钢筋混凝土结构',
#  'D.地下防水',
#  'A.浇筑与原结构相同等级的混凝土',
#  'B.浇筑比原结构提高一等级的微膨胀混凝土',
#  'C.接茬部分未剔凿直接浇筑混凝土',
#  'D.后浇带模板支撑重新搭设后浇筑混凝土',
#  'A.初凝前',
#  'B.初凝后',
#  'C.终凝前',
#  'D.终凝后',
#  'A.承受由于弯矩作用而产生的拉力',
#  'B.承受由于弯矩作用而产生的压力',
#  'C.承受剪力',
#  'D.承受因砼收缩和温度变化产生的应力',
#  'A.屈服强度',
#  'B.疲劳强度',
#  'C.抗拉强度',
#  'D.伸长率',
#  'A.Ⅰ',
#  'B.Ⅱ',
#  'C.Ⅲ',
#  'D.Ⅱ、Ⅲ',
#  'A.15℃',
#  'B.10℃',
#  'C.5℃',
#  'D.0℃',
#  'A.渗漏',
#  'B.腐',
#  'C.滑',
#  'D.软化',
#  'A.90',
#  'B.60',
#  'C.30',
#  'D.28',
#  'A.1/1000~3/1000',
#  'B.1/100-3/100',
#  'C.3/1000-5/1000',
#  'D.5/1000-7/1000',
#  ...]

# %%
import xlwt
book = xlwt.Workbook(encoding='utf-8')
sheet1 = book.add_sheet('test')
for i in range(len(form[1])):
    sheet1.write(i,0,form[1][i])
book.save(r'final.xls')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-45e49d653842> in <module>()
#       4 for i in range(len(form[1])):
#       5     sheet1.write(i,0,form[1][i])
# ----> 6 book.save(r'final.xls')
#
# ~\Anaconda3\lib\site-packages\xlwt\Workbook.py in save(self, filename_or_stream)
#     708
#     709         doc = CompoundDoc.XlsDoc()
# --> 710         doc.save(filename_or_stream, self.get_biff_data())
#     711
#     712
#
# ~\Anaconda3\lib\site-packages\xlwt\CompoundDoc.py in save(self, file_name_or_filelike_obj, stream)
#     260         we_own_it = not hasattr(f, 'write')
#     261         if we_own_it:
# --> 262             f = open(file_name_or_filelike_obj, 'w+b')
#     263         f.write(self.header)
#     264         f.write(self.packed_MSAT_1st)
#
# PermissionError: [Errno 13] Permission denied: 'final.xls'

# %%
' '.join(list(grouped.get_group(100)))
