# %%
file = open('ans.txt')

# %%
ans = file.read()

# %%
ans_pat = '[A-G]+'

# %%
import re
#ans_re = ''.join(re.split(r'[^A-D]', ans))
ans_re =' '.join(re.findall(r'[A-G]', ans))

# %%
ans_re.split()
# Out:
# ['A',
#  'B',
#  'D',
#  'A',
#  'A',
#  'C',
#  'A',
#  'A',
#  'A',
#  'D',
#  'D',
#  'B',
#  'C',
#  'A',
#  'A',
#  'A',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'C',
#  'D',
#  'A',
#  'C',
#  'A',
#  'B',
#  'D',
#  'C',
#  'A',
#  'C',
#  'C',
#  'A',
#  'C',
#  'C',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'D',
#  'B',
#  'A',
#  'A',
#  'D',
#  'B',
#  'A',
#  'B',
#  'A',
#  'B',
#  'D',
#  'B',
#  'C',
#  'A',
#  'A',
#  'D',
#  'B',
#  'A',
#  'D',
#  'C',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'B',
#  'C',
#  'D',
#  'D',
#  'E',
#  'D',
#  'A',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'B',
#  'A',
#  'C',
#  'B',
#  'C',
#  'A',
#  'B',
#  'B',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'B',
#  'B',
#  'D',
#  'C',
#  'D',
#  'A',
#  'C',
#  'D',
#  'A',
#  'C',
#  'C',
#  'C',
#  'A',
#  'A',
#  'C',
#  'C',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'C',
#  'A',
#  'C',
#  'D',
#  'A',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'D',
#  'D',
#  'B',
#  'A',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'D',
#  'D',
#  'C',
#  'C',
#  'A',
#  'D',
#  'B',
#  'B',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'C',
#  'D',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'C',
#  'B',
#  'C',
#  'B',
#  'C',
#  'A',
#  'C',
#  'D',
#  'D',
#  'C',
#  'D',
#  'A',
#  'D',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'A',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'C',
#  'D',
#  'D',
#  'B',
#  'C',
#  'A',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'D',
#  'C',
#  'A',
#  'A',
#  'B',
#  'D',
#  'A',
#  'D',
#  'A',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'A',
#  'B',
#  'D',
#  'D',
#  'A',
#  'C',
#  'B',
#  'C',
#  'D',
#  'D',
#  'A',
#  'D',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'C',
#  'A',
#  'D',
#  'A',
#  'D',
#  'A',
#  'A',
#  'D',
#  'B',
#  'A',
#  'B',
#  'A',
#  'C',
#  'C',
#  'B',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'A',
#  'D',
#  'B',
#  'D',
#  'A',
#  'D',
#  'B',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'C',
#  'C',
#  'A',
#  'D',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'D',
#  'C',
#  'C',
#  'A',
#  'C',
#  'B',
#  'C',
#  'D',
#  'D',
#  'C',
#  'D',
#  'D',
#  'C',
#  'C',
#  'A',
#  'B',
#  'A',
#  'D',
#  'B',
#  'C',
#  'D',
#  'B',
#  'D',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'C',
#  'C',
#  'D',
#  'A',
#  'C',
#  'A',
#  'C',
#  'A',
#  'D',
#  'D',
#  'B',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'B',
#  'B',
#  'C',
#  'D',
#  'B',
#  'B',
#  'B',
#  'A',
#  'C',
#  'B',
#  'B',
#  'C',
#  'B',
#  'D',
#  'D',
#  'D',
#  'A',
#  'C',
#  'A',
#  'D',
#  'B',
#  'C',
#  'C',
#  'A',
#  'C',
#  'D',
#  'A',
#  'A',
#  'D',
#  'A',
#  'B',
#  'D',
#  'A',
#  'C',
#  'C',
#  'A',
#  'C',
#  'B',
#  'C',
#  'B',
#  'B',
#  'D',
#  'B',
#  'B',
#  'C',
#  'C',
#  'D',
#  'B',
#  'D',
#  'C',
#  'A',
#  'D',
#  'C',
#  'B',
#  'B',
#  'C',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'D',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'D',
#  'A',
#  'C',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'C',
#  'D',
#  'B',
#  'D',
#  'A',
#  'C',
#  'D',
#  'A',
#  'C',
#  'C',
#  'A',
#  'A',
#  'D',
#  'B',
#  'A',
#  'B',
#  'C',
#  'A',
#  'A',
#  'D',
#  'B',
#  'B',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'B',
#  'A',
#  'B',
#  'D',
#  'A',
#  'C',
#  'A',
#  'D',
#  'D',
#  'B',
#  'D',
#  'A',
#  'A',
#  'D',
#  'C',
#  'C',
#  'A',
#  'B',
#  'A',
#  'A',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'B',
#  'D',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'D',
#  'D',
#  'B',
#  'D',
#  'A',
#  'C',
#  'D',
#  'C',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A']

# %%
import xlwt
book = xlwt.Workbook(encoding='utf-8')
sheet1 = book.add_sheet('test')
for i in range(len(ans_re)):
    sheet1.write(i,0,ans_re[i])
book.save(r'ans.xls')
